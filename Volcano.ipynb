# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/mattkram/9684863843254402942dfede27af2cb7/raw/2590dd8185b833aacf247c0595edbb07a025a6d7/Smithsonian_VOTW_Holocene_Volcanoes.csv'
df = pd.read_csv(url)

df.head(100)
# Out:
#                                                   FID  Volcano_Number  \
# 0   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210010
# 1   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210020
# 2   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210030
# 3   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          210040
# 4   Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          211004
# ..                                                ...             ...
# 95  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          221290
# 96  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          221291
# 97  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          221292
# 98  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          221311
# 99  Smithsonian_VOTW_Holocene_Volcanoes.fid--d9082...          221320
#
#                  Volcano_Name Primary_Volcano_Type  Last_Eruption_Year  \
# ...

# %%
plt.ylabel('Elevation')
plt.plot(df['Elevation'], linestyle='solid', marker='o', markersize=3)

# %%
max(df['Elevation']), min(df['Elevation'])
# Out:
# (6879, -5700)

# %%
x = df['Longitude'] 
y = df['Latitude']  

heatmap, xedges, yedges = np.histogram2d(y, x, bins=25)
# bins --- tells matrix size like(40*40 for bins=40)

plt.imshow(heatmap.T, origin='lower', cmap='hot', interpolation='bilinear',
           extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
# interpolate --- tells type of shading for heatmap
# xedges and yegdes --- contains values of x and y parameter

plt.colorbar(label='Count')
plt.title('Heatmap of Points')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
